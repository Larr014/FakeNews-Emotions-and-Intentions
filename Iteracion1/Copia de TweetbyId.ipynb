# %%
import tweepy                   # Python wrapper around Twitter API
from google.colab import drive  # to mount Drive to Colab notebook
import json
import csv
from datetime import date
from datetime import datetime
import time
import pandas as pd

import numpy as np

# %%
# Connect Google Drive to Colab
drive.mount('/content/gdrive')
# Create a variable to store the data path on your drive
path = './gdrive/My Drive/'
# Out:
# Mounted at /content/gdrive

# %%
# Load Twitter API secrets from an external JSON file
api_key = ''
api_secret_key = ''
access_token = ''
access_token_secret = ''
# Connect to Twitter API using the secrets
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
def get_tweet_by_id(id):
    tweet = api.get_status(id)
    return tweet.text

# %%
a = get_tweet_by_id(972900916113346561)
a
# Out:
# 'Court Orders Obama To Pay $400 Million In Restitution: https://t.co/ESLzedouVs'

# %%
gossipcopFake=pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/gossipcop_fake.csv')

# %%
gossipcopFake.head()
# Out:
#                      id  ...                                          tweet_ids
# 0  gossipcop-2493749932  ...  284329075902926848\t284332744559968256\t284335...
# 1  gossipcop-4580247171  ...  992895508267130880\t992897935418503169\t992899...
# 2   gossipcop-941805037  ...  853359353532829696\t853359576543920128\t853359...
# 3  gossipcop-2547891536  ...  988821905196158981\t988824206556172288\t988825...
# 4  gossipcop-5476631226  ...  955792793632432131\t955795063925301249\t955798...
#
# [5 rows x 4 columns]

# %%
gossipcopFake['tweet_ids'][0]
# Out:
# '284329075902926848\t284332744559968256\t284335412590297089\t284359918792880128\t284385385151332353\t284456388833452032\t284644878267318273\t284656558963564545\t284705391965794304\t284705391957401601\t284762425553723392\t284766089827721217\t284769766806257664\t284769769490620416\t284769775442337792\t284769772980301824\t284769778655186944\t284769777073917952\t284771913753042944\t284902943201837056\t284918939975303169\t285592266716884993\t285635421872979969\t285635516924301313\t285731324101287937\t295954533555793920\t296639632710459392\t296651276626825216\t700137152143699968\t700501642412560384\t700599457767890944\t700925213031141376\t757598980373045248\t757614017808437248\t757810204448743425\t757855454886293504\t818454872299163649\t818532208990371841\t818622382524997632\t818623644737871872\t824328059335692290\t840237926642536449\t840277988067430400\t840305556736872448\t840312641042104320\t840320383437877248\t840321378150670336\t840325449389600768\t840346792671698945\t84035911575499981
# ...

# %%
gossipcopFake['tweet_ids'][0].split()
# Out:
# ['284329075902926848',
#  '284332744559968256',
#  '284335412590297089',
#  '284359918792880128',
#  '284385385151332353',
#  '284456388833452032',
#  '284644878267318273',
#  '284656558963564545',
#  '284705391965794304',
#  '284705391957401601',
#  '284762425553723392',
#  '284766089827721217',
#  '284769766806257664',
#  '284769769490620416',
#  '284769775442337792',
#  '284769772980301824',
#  '284769778655186944',
#  '284769777073917952',
#  '284771913753042944',
#  '284902943201837056',
#  '284918939975303169',
#  '285592266716884993',
#  '285635421872979969',
#  '285635516924301313',
#  '285731324101287937',
#  '295954533555793920',
#  '296639632710459392',
#  '296651276626825216',
#  '700137152143699968',
#  '700501642412560384',
#  '700599457767890944',
#  '700925213031141376',
#  '757598980373045248',
#  '757614017808437248',
#  '757810204448743425',
#  '757855454886293504',
#  '818454872299163649',
#  '818532208990371841',
#  '818622382524997632',
#  '818623644737871872',
# ...

# %%
len(gossipcopFake['tweet_ids'])
# Out:
# 5323

# %%
def search_tweet_by_id(fileName,df,columName,label):
  tweets = []
  for i in range(2193,len(df[columName])):
    tweets.clear();
    try:
      dfSplit = df[columName][i].split()
      for j in range(len(dfSplit)):
        try:
          tweets.append(get_tweet_by_id(dfSplit[j]))
        except:
          pass
      if i%5==0:
        print(f'{(i*100)/len(df[columName])}') 
    #print(tweets)
      data = {'Tweet':  tweets,
           'label': label,
         
            }
      dfr = pd.DataFrame(data,columns=['Tweet',"label"])
      dfr.to_csv('/content/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/'+fileName+str(i)+'.csv') 
    except:
      pass
    
    
  return tweets

# %%
tweets = []
tweets = search_tweet_by_id('gossipcopFake',gossipcopFake,'tweet_ids','fake')

# %%
data = {'Tweet':  tweets,
           'label': label,
         
            }
df = pd.DataFrame(data,columns=['Tweet',"label"])
df.to_csv('/content/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/gossipcopFake_convertido.csv')
