# %% [markdown]
# # Introducción
#
# *   Se presenta como problemática la clasificación de flores, explicitamente de tres tipos: Iris Setosa, Iris Virginica e Iris Versicolor.
# *   El objetivo del laboratorio es diseñar un clasificador neuronal poco profundo que permita identificar que tipo de flor es en base a cuatro caracteristicas, a saber, largo del sepalo, ancho del sepalo, largo del petalo y ancho del petalo
#
#
# # Experimentos
#
# *   Se utilizará la base de datos iris.csv
# *   Carga de datos
# *   Separacion de los datos: Conjunto de entrenamiento, conjunto de prueba y conjunto de validación
# *   Diseño del modelo
# * Entrenamiento
# * Validación
#
# ## Carga de la base de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torchvision
from torchvision import transforms, datasets
import numpy as np
#PyTorch permite trabajar con CUDA para realizar las operaciones en la GPU
torch.cuda.is_available()
cuda0 = torch.device('cuda:0')
torch.cuda.current_device()
print(torch.cuda.get_device_name(0))
torch.cuda.empty_cache()
# Out:
# Tesla P100-PCIE-16GB

# %% [markdown]
# # Nueva sección

# %%
acaaaaa

# %%
print(f'{X1_trainp1.shape} {y1_trainp1.shape}')
print(f'{X1_trainp2.shape} {y1_trainp2.shape}')
print(f'{X1_trainp3.shape} {y1_trainp3.shape}')

# %% [markdown]
# ## red

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K 
def crearModelo():
  K.clear_session( )
  model = Sequential()
  model.add(Dense(1000,  activation='relu'))
  model.add(Dense(2,  activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
  return model

# %% [markdown]
# ## Modelo 1
#
# Del conjunto de datos se tiene un total de 150 observaciones, de estas se separan en tres nuevos conjuntos; conjunto de entrenamiento 84 observaciones, conjunto de prueba 30 observaciones y conjunto de validacion 36 observaciones, correspondiendo a un 56%,  20% y 24% respectivamente.

# %%
# %time X1_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_train/X1_train_tensorp0.pt')
# %time X1_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_train/X1_train_tensorp1.pt')
# %time X1_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_train/X1_train_tensorp2.pt')
# %time y1_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_train/y1_train_tensorp0.pt')
# %time y1_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_train/y1_train_tensorp1.pt')
# %time y1_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_train/y1_train_tensorp2.pt')
# Out:
# CPU times: user 1.6 s, sys: 3.02 s, total: 4.63 s
# Wall time: 28.1 s
# CPU times: user 509 ms, sys: 1.63 s, total: 2.14 s
# Wall time: 24.2 s
# CPU times: user 457 ms, sys: 1.48 s, total: 1.93 s
# Wall time: 22 s
# CPU times: user 8.8 ms, sys: 2.49 ms, total: 11.3 ms
# Wall time: 1.43 s
# CPU times: user 6.89 ms, sys: 1.51 ms, total: 8.39 ms
# Wall time: 711 ms
# CPU times: user 9.54 ms, sys: 364 µs, total: 9.91 ms
# Wall time: 820 ms

# %%
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
y1_trainp1 = to_categorical(y1_trainp1.cpu(), num_classes=2)
y1_trainp2 = to_categorical(y1_trainp2.cpu(), num_classes=2)
y1_trainp3 = to_categorical(y1_trainp3.cpu(), num_classes=2)

# %% [markdown]
# Modelo 1

# %%
modelo1  = crearModelo()

# %%
history = modelo1.fit(np.asarray(X1_trainp1.cpu()), np.asarray(y1_trainp1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 782/782 - 9s - loss: 0.3141 - categorical_accuracy: 0.8644 - 9s/epoch - 11ms/step
# Epoch 2/20
# 782/782 - 5s - loss: 0.1333 - categorical_accuracy: 0.9486 - 5s/epoch - 7ms/step
# Epoch 3/20
# 782/782 - 5s - loss: 0.0560 - categorical_accuracy: 0.9806 - 5s/epoch - 7ms/step
# Epoch 4/20
# 782/782 - 6s - loss: 0.0197 - categorical_accuracy: 0.9944 - 6s/epoch - 7ms/step
# Epoch 5/20
# 782/782 - 5s - loss: 0.0062 - categorical_accuracy: 0.9986 - 5s/epoch - 7ms/step
# Epoch 6/20
# 782/782 - 6s - loss: 0.0022 - categorical_accuracy: 0.9995 - 6s/epoch - 7ms/step
# Epoch 7/20
# 782/782 - 5s - loss: 0.0011 - categorical_accuracy: 0.9998 - 5s/epoch - 7ms/step
# Epoch 8/20
# 782/782 - 5s - loss: 7.1509e-04 - categorical_accuracy: 1.0000 - 5s/epoch - 7ms/step
# Epoch 9/20
# 782/782 - 5s - loss: 5.7378e-04 - categorical_accuracy: 0.9999 - 5s/epoch - 7ms/step
# Epoch 10/20
# 782/782 - 5s - loss: 0.0013 - categorical_accuracy: 0.9997 - 5s/epoch - 7ms/step
# Epoch 11/20
# ...

# %%
history = modelo1.fit(np.asarray(X1_trainp2.cpu()), np.asarray(y1_trainp2)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 782/782 - 5s - loss: 0.2238 - categorical_accuracy: 0.9226 - 5s/epoch - 7ms/step
# Epoch 2/20
# 782/782 - 5s - loss: 0.0561 - categorical_accuracy: 0.9824 - 5s/epoch - 7ms/step
# Epoch 3/20
# 782/782 - 5s - loss: 0.0171 - categorical_accuracy: 0.9965 - 5s/epoch - 6ms/step
# Epoch 4/20
# 782/782 - 5s - loss: 0.0059 - categorical_accuracy: 0.9996 - 5s/epoch - 7ms/step
# Epoch 5/20
# 782/782 - 5s - loss: 0.0024 - categorical_accuracy: 0.9999 - 5s/epoch - 7ms/step
# Epoch 6/20
# 782/782 - 5s - loss: 0.0012 - categorical_accuracy: 1.0000 - 5s/epoch - 7ms/step
# Epoch 7/20
# 782/782 - 5s - loss: 6.4311e-04 - categorical_accuracy: 0.9999 - 5s/epoch - 6ms/step
# Epoch 8/20
# 782/782 - 5s - loss: 3.9216e-04 - categorical_accuracy: 1.0000 - 5s/epoch - 7ms/step
# Epoch 9/20
# 782/782 - 5s - loss: 3.1617e-04 - categorical_accuracy: 0.9999 - 5s/epoch - 7ms/step
# Epoch 10/20
# 782/782 - 5s - loss: 2.9497e-04 - categorical_accuracy: 0.9999 - 5s/epoch - 7ms/step
# Epoch 11/20
# ...

# %%
history = modelo1.fit(np.asarray(X1_trainp3.cpu()), np.asarray(y1_trainp3)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 737/737 - 3s - loss: 0.2069 - categorical_accuracy: 0.9410 - 3s/epoch - 5ms/step
# Epoch 2/20
# 737/737 - 3s - loss: 0.0245 - categorical_accuracy: 0.9931 - 3s/epoch - 5ms/step
# Epoch 3/20
# 737/737 - 3s - loss: 0.0080 - categorical_accuracy: 0.9986 - 3s/epoch - 5ms/step
# Epoch 4/20
# 737/737 - 3s - loss: 0.0034 - categorical_accuracy: 0.9997 - 3s/epoch - 5ms/step
# Epoch 5/20
# 737/737 - 4s - loss: 0.0018 - categorical_accuracy: 0.9998 - 4s/epoch - 5ms/step
# Epoch 6/20
# 737/737 - 4s - loss: 9.8549e-04 - categorical_accuracy: 0.9999 - 4s/epoch - 5ms/step
# Epoch 7/20
# 737/737 - 3s - loss: 6.0100e-04 - categorical_accuracy: 0.9999 - 3s/epoch - 5ms/step
# Epoch 8/20
# 737/737 - 3s - loss: 4.0965e-04 - categorical_accuracy: 1.0000 - 3s/epoch - 5ms/step
# Epoch 9/20
# 737/737 - 3s - loss: 3.1722e-04 - categorical_accuracy: 0.9999 - 3s/epoch - 5ms/step
# Epoch 10/20
# 737/737 - 3s - loss: 1.5205e-04 - categorical_accuracy: 1.0000 - 3s/epoch - 5ms/step
# Epoch 11/20
# ...

# %%
modelo1.save('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo1DenseTrain.h5')

# %%
from keras.models import load_model
modelo1 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo1DenseTrain.h5')

# %%
# %time X1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp0.pt')
# %time X1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp1.pt')
# %time X1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp2.pt')
# %time y1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp0.pt')
# %time y1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp1.pt')
# %time y1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp2.pt')
# %time X1_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_val/X1_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time X1_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_val/X1_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time X1_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_val/X1_val_tensorp2.pt',map_location=torch.device('cpu'))
# %time y1_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_val/y1_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time y1_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_val/y1_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time y1_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_val/y1_val_tensorp2.pt',map_location=torch.device('cpu'))
# Out:
# CPU times: user 180 ms, sys: 636 ms, total: 816 ms
# Wall time: 1.55 s
# CPU times: user 137 ms, sys: 581 ms, total: 718 ms
# Wall time: 1.14 s
# CPU times: user 177 ms, sys: 712 ms, total: 889 ms
# Wall time: 1.33 s
# CPU times: user 1.58 ms, sys: 1.78 ms, total: 3.35 ms
# Wall time: 3.7 ms
# CPU times: user 2.8 ms, sys: 84 µs, total: 2.88 ms
# Wall time: 2.8 ms
# CPU times: user 2.51 ms, sys: 255 µs, total: 2.77 ms
# Wall time: 2.66 ms
# CPU times: user 67.1 ms, sys: 923 ms, total: 990 ms
# Wall time: 1.53 s
# CPU times: user 64.5 ms, sys: 1.2 s, total: 1.26 s
# Wall time: 2.59 s
# CPU times: user 68.7 ms, sys: 1.36 s, total: 1.43 s
# Wall time: 10.8 s
# CPU times: user 4.01 ms, sys: 3.97 ms, total: 7.98 ms
# Wall time: 502 ms
# CPU times: user 6.16 ms, sys: 0 ns, total: 6.16 ms
# Wall time: 481 ms
# CPU times: user 6.4 ms, sys: 1.86 ms, total: 8.27 ms
# Wall time: 484 ms

# %%
from tensorflow.keras.utils import to_categorical
y1_valp1 = to_categorical(y1_valp1.cpu(), num_classes=2)
y1_valp2 = to_categorical(y1_valp2.cpu(), num_classes=2)
y1_valp3 = to_categorical(y1_valp3.cpu(), num_classes=2)

y1_testp1 = to_categorical(y1_testp1.cpu(), num_classes=2)
y1_testp2 = to_categorical(y1_testp2.cpu(), num_classes=2)
y1_testp3 = to_categorical(y1_testp3.cpu(), num_classes=2)

# %%
#validacion
modelo1.evaluate(np.asarray(X1_valp1.cpu()), np.asarray(y1_valp1),verbose=2)
modelo1.evaluate(np.asarray(X1_valp2.cpu()), np.asarray(y1_valp2),verbose=2)
modelo1.evaluate(np.asarray(X1_valp3.cpu()), np.asarray(y1_valp3),verbose=2)
# Out:
# 469/469 - 2s - loss: 0.3723 - categorical_accuracy: 0.9429 - 2s/epoch - 5ms/step
# 469/469 - 2s - loss: 0.3646 - categorical_accuracy: 0.9461 - 2s/epoch - 3ms/step
# 471/471 - 2s - loss: 0.3797 - categorical_accuracy: 0.9447 - 2s/epoch - 3ms/step
# [0.37970805168151855, 0.9446882009506226]

# %%
modelo1.save('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo1DenseEvaluate.h5')

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
y1predict = {}
with torch.no_grad():
  y1_test = np.concatenate((y1_testp1, y1_testp2,y1_testp3), axis=0)
  X1_test = torch.cat((X1_testp1.cpu(),X1_testp2.cpu(),X1_testp3.cpu()),0)
  y1_predictions = modelo1.predict(np.asarray(X1_test),verbose=2).round()
  print(len(y1_predictions))
  confusion = multilabel_confusion_matrix(y1_test,y1_predictions)
  print(f"acc: {accuracy_score(y1_test,y1_predictions)}")
  print(f"precision: {precision_score(y1_test,y1_predictions,average='macro')}")
  print(f"recall: {recall_score(y1_test,y1_predictions,average='macro')}")
  print(f"f1: {f1_score(y1_test,y1_predictions,average='micro')}")
  confusion_display = ConfusionMatrixDisplay(confusion[0],display_labels=['fake','noFake']).plot(values_format='d')
# Out:
# 986/986 - 2s - 2s/epoch - 2ms/step
# 31529
# acc: 0.9453518982524025
# precision: 0.9457077468851985
# recall: 0.9411164047414773
# f1: 0.9453518982524025

# %% [markdown]
# ## Modelo 2

# %%
modelo2  = crearModelo()

# %%
# %time X2_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_train/X2_train_tensorp0.pt')
# %time X2_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_train/X2_train_tensorp1.pt')
# %time X2_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_train/X2_train_tensorp2.pt')
# %time y2_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_train/y2_train_tensorp0.pt')
# %time y2_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_train/y2_train_tensorp1.pt')
# %time y2_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_train/y2_train_tensorp2.pt')
# Out:
# CPU times: user 561 ms, sys: 1.85 s, total: 2.41 s
# Wall time: 17.1 s
# CPU times: user 579 ms, sys: 1.17 s, total: 1.75 s
# Wall time: 11.7 s
# CPU times: user 532 ms, sys: 1.12 s, total: 1.65 s
# Wall time: 15.1 s
# CPU times: user 7.94 ms, sys: 16.7 ms, total: 24.6 ms
# Wall time: 837 ms
# CPU times: user 3.82 ms, sys: 1.1 ms, total: 4.92 ms
# Wall time: 392 ms
# CPU times: user 4.57 ms, sys: 354 µs, total: 4.93 ms
# Wall time: 388 ms

# %%
from tensorflow.keras.utils import to_categorical

y2_trainp1 = to_categorical(y2_trainp1.cpu(), num_classes=2)
y2_trainp2 = to_categorical(y2_trainp2.cpu(), num_classes=2)
y2_trainp3 = to_categorical(y2_trainp3.cpu(), num_classes=2)

# %%
history = modelo2.fit(np.asarray(X2_trainp1.cpu()), np.asarray(y2_trainp1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 782/782 - 10s - loss: 0.3090 - categorical_accuracy: 0.8660 - 10s/epoch - 13ms/step
# Epoch 2/20
# 782/782 - 5s - loss: 0.1294 - categorical_accuracy: 0.9514 - 5s/epoch - 6ms/step
# Epoch 3/20
# 782/782 - 5s - loss: 0.0553 - categorical_accuracy: 0.9817 - 5s/epoch - 6ms/step
# Epoch 4/20
# 782/782 - 5s - loss: 0.0195 - categorical_accuracy: 0.9944 - 5s/epoch - 6ms/step
# Epoch 5/20
# 782/782 - 5s - loss: 0.0068 - categorical_accuracy: 0.9986 - 5s/epoch - 6ms/step
# Epoch 6/20
# 782/782 - 4s - loss: 0.0028 - categorical_accuracy: 0.9994 - 4s/epoch - 6ms/step
# Epoch 7/20
# 782/782 - 5s - loss: 0.0014 - categorical_accuracy: 0.9997 - 5s/epoch - 6ms/step
# Epoch 8/20
# 782/782 - 5s - loss: 9.9623e-04 - categorical_accuracy: 0.9997 - 5s/epoch - 6ms/step
# Epoch 9/20
# 782/782 - 5s - loss: 6.8298e-04 - categorical_accuracy: 0.9998 - 5s/epoch - 6ms/step
# Epoch 10/20
# 782/782 - 5s - loss: 6.3984e-04 - categorical_accuracy: 0.9998 - 5s/epoch - 6ms/step
# Epoch 11/20
# ...

# %%
history = modelo2.fit(np.asarray(X2_trainp2.cpu()), np.asarray(y2_trainp2)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 782/782 - 4s - loss: 0.2183 - categorical_accuracy: 0.9249 - 4s/epoch - 6ms/step
# Epoch 2/20
# 782/782 - 4s - loss: 0.0543 - categorical_accuracy: 0.9837 - 4s/epoch - 6ms/step
# Epoch 3/20
# 782/782 - 4s - loss: 0.0163 - categorical_accuracy: 0.9972 - 4s/epoch - 6ms/step
# Epoch 4/20
# 782/782 - 4s - loss: 0.0052 - categorical_accuracy: 0.9996 - 4s/epoch - 6ms/step
# Epoch 5/20
# 782/782 - 4s - loss: 0.0022 - categorical_accuracy: 0.9999 - 4s/epoch - 6ms/step
# Epoch 6/20
# 782/782 - 4s - loss: 0.0011 - categorical_accuracy: 1.0000 - 4s/epoch - 6ms/step
# Epoch 7/20
# 782/782 - 4s - loss: 5.4132e-04 - categorical_accuracy: 1.0000 - 4s/epoch - 6ms/step
# Epoch 8/20
# 782/782 - 4s - loss: 3.1542e-04 - categorical_accuracy: 1.0000 - 4s/epoch - 6ms/step
# Epoch 9/20
# 782/782 - 4s - loss: 1.8071e-04 - categorical_accuracy: 1.0000 - 4s/epoch - 6ms/step
# Epoch 10/20
# 782/782 - 4s - loss: 1.0821e-04 - categorical_accuracy: 1.0000 - 4s/epoch - 6ms/step
# Epoch 11/20
# ...

# %%
history = modelo2.fit(np.asarray(X2_trainp3.cpu()), np.asarray(y2_trainp3)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 737/737 - 3s - loss: 0.2095 - categorical_accuracy: 0.9386 - 3s/epoch - 4ms/step
# Epoch 2/20
# 737/737 - 3s - loss: 0.0291 - categorical_accuracy: 0.9927 - 3s/epoch - 4ms/step
# Epoch 3/20
# 737/737 - 3s - loss: 0.0098 - categorical_accuracy: 0.9984 - 3s/epoch - 4ms/step
# Epoch 4/20
# 737/737 - 3s - loss: 0.0042 - categorical_accuracy: 0.9996 - 3s/epoch - 4ms/step
# Epoch 5/20
# 737/737 - 3s - loss: 0.0022 - categorical_accuracy: 0.9998 - 3s/epoch - 4ms/step
# Epoch 6/20
# 737/737 - 3s - loss: 0.0012 - categorical_accuracy: 0.9998 - 3s/epoch - 4ms/step
# Epoch 7/20
# 737/737 - 3s - loss: 7.4823e-04 - categorical_accuracy: 0.9999 - 3s/epoch - 4ms/step
# Epoch 8/20
# 737/737 - 3s - loss: 6.1506e-04 - categorical_accuracy: 0.9999 - 3s/epoch - 4ms/step
# Epoch 9/20
# 737/737 - 3s - loss: 2.6516e-04 - categorical_accuracy: 1.0000 - 3s/epoch - 4ms/step
# Epoch 10/20
# 737/737 - 3s - loss: 1.6888e-04 - categorical_accuracy: 1.0000 - 3s/epoch - 4ms/step
# Epoch 11/20
# ...

# %%
modelo2.save('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo2DenseTrain.h5')

# %%
from keras.models import load_model
modelo2 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo2DenseTrain.h5')

# %%
# %time X2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp0.pt')
# %time X2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp1.pt')
# %time X2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp2.pt')
# %time y2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp0.pt')
# %time y2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp1.pt')
# %time y2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp2.pt')
# %time X2_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_val/X2_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time X2_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_val/X2_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time X2_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_val/X2_val_tensorp2.pt',map_location=torch.device('cpu'))
# %time y2_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_val/y2_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time y2_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_val/y2_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time y2_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_val/y2_val_tensorp2.pt',map_location=torch.device('cpu'))
# Out:
# CPU times: user 248 ms, sys: 686 ms, total: 935 ms
# Wall time: 3.31 s
# CPU times: user 259 ms, sys: 426 ms, total: 686 ms
# Wall time: 3.29 s
# CPU times: user 269 ms, sys: 548 ms, total: 817 ms
# Wall time: 2.78 s
# CPU times: user 1.39 ms, sys: 837 µs, total: 2.23 ms
# Wall time: 2.28 ms
# CPU times: user 1.98 ms, sys: 0 ns, total: 1.98 ms
# Wall time: 1.9 ms
# CPU times: user 1.96 ms, sys: 0 ns, total: 1.96 ms
# Wall time: 2.01 ms
# CPU times: user 17.3 ms, sys: 807 ms, total: 824 ms
# Wall time: 1.27 s
# CPU times: user 0 ns, sys: 1.03 s, total: 1.03 s
# Wall time: 1.28 s
# CPU times: user 0 ns, sys: 1.13 s, total: 1.13 s
# Wall time: 1.46 s
# CPU times: user 0 ns, sys: 918 µs, total: 918 µs
# Wall time: 1.93 ms
# CPU times: user 0 ns, sys: 2.17 ms, total: 2.17 ms
# Wall time: 2.17 ms
# CPU times: user 0 ns, sys: 2.08 ms, total: 2.08 ms
# Wall time: 2.1 ms

# %%
from tensorflow.keras.utils import to_categorical
y2_valp1 = to_categorical(y2_valp1.cpu(), num_classes=2)
y2_valp2 = to_categorical(y2_valp2.cpu(), num_classes=2)
y2_valp3 = to_categorical(y2_valp3.cpu(), num_classes=2)

y2_testp1 = to_categorical(y2_testp1.cpu(), num_classes=2)
y2_testp2 = to_categorical(y2_testp2.cpu(), num_classes=2)
y2_testp3 = to_categorical(y2_testp3.cpu(), num_classes=2)

# %%
#validacion
modelo2.evaluate(np.asarray(X2_valp1.cpu()), np.asarray(y2_valp1),verbose=2)
modelo2.evaluate(np.asarray(X2_valp2.cpu()), np.asarray(y2_valp2),verbose=2)
modelo2.evaluate(np.asarray(X2_valp3.cpu()), np.asarray(y2_valp3),verbose=2)
# Out:
# 469/469 - 2s - loss: 0.3491 - categorical_accuracy: 0.9267 - 2s/epoch - 3ms/step
# 469/469 - 1s - loss: 0.3315 - categorical_accuracy: 0.9289 - 1s/epoch - 3ms/step
# 471/471 - 1s - loss: 0.3171 - categorical_accuracy: 0.9347 - 1s/epoch - 2ms/step
# [0.3170586824417114, 0.9347161054611206]

# %%
modelo2.save('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo2DenseEvaluate.h5')

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix

with torch.no_grad():
  y2_test = np.concatenate((y2_testp1, y2_testp2,y2_testp3), axis=0)
  X2_test = torch.cat((X2_testp1.cpu(),X2_testp2.cpu(),X2_testp3.cpu()),0)
  y2_predictions = modelo2.predict(np.asarray(X2_test),verbose=2).round()
  print(len(y2_predictions))
  confusion = multilabel_confusion_matrix(y2_test,y2_predictions)
  print(f"acc: {accuracy_score(y2_test,y2_predictions)}")
  print(f"precision: {precision_score(y2_test,y2_predictions,average='macro')}")
  print(f"recall: {recall_score(y2_test,y2_predictions,average='macro')}")
  print(f"f1: {f1_score(y2_test,y2_predictions,average='micro')}")
  confusion_display = ConfusionMatrixDisplay(confusion[0],display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# ## Modelo 3

# %%
# %time X3_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_train/X3_train_tensorp0.pt')
# %time X3_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_train/X3_train_tensorp1.pt')
# %time X3_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_train/X3_train_tensorp2.pt')
# %time y3_trainp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_train/y3_train_tensorp0.pt')
# %time y3_trainp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_train/y3_train_tensorp1.pt')
# %time y3_trainp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_train/y3_train_tensorp2.pt')

# %%
print(X3_trainp1.shape)
print(X3_trainp2.shape)
print(X3_trainp3.shape)

# %%
from tensorflow.keras.utils import to_categorical

y3_trainp1 = to_categorical(y3_trainp1.cpu(), num_classes=2)
y3_trainp2 = to_categorical(y3_trainp2.cpu(), num_classes=2)
y3_trainp3 = to_categorical(y3_trainp3.cpu(), num_classes=2)

# %%
modelo3  = crearModelo()

# %%
history = modelo3.fit(np.asarray(X3_trainp1.cpu()), np.asarray(y3_trainp1)
                      , epochs=20, verbose=2)

# %%
history = modelo3.fit(np.asarray(X3_trainp2.cpu()), np.asarray(y3_trainp2)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)

# %%
history = modelo3.fit(np.asarray(X3_trainp3.cpu()), np.asarray(y3_trainp3)#,validation_data=(np.asarray(X1_val),y1_val1)
                      , epochs=20, verbose=2)

# %%
modelo3.save('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo3DenseTrain.h5')

# %%
from keras.models import load_model
modelo3 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo3DenseTrain.h5')

# %%
# %time X3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp0.pt')
# %time X3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp1.pt')
# %time X3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp2.pt')
# %time y3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp0.pt')
# %time y3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp1.pt')
# %time y3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp2.pt')
# %time X3_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_val/X3_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time X3_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_val/X3_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time X3_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_val/X3_val_tensorp2.pt',map_location=torch.device('cpu'))
# %time y3_valp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_val/y3_val_tensorp0.pt',map_location=torch.device('cpu'))
# %time y3_valp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_val/y3_val_tensorp1.pt',map_location=torch.device('cpu'))
# %time y3_valp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_val/y3_val_tensorp2.pt',map_location=torch.device('cpu'))
# Out:
# CPU times: user 294 ms, sys: 645 ms, total: 939 ms
# Wall time: 3.32 s
# CPU times: user 250 ms, sys: 429 ms, total: 679 ms
# Wall time: 3.29 s
# CPU times: user 282 ms, sys: 543 ms, total: 825 ms
# Wall time: 3.81 s
# CPU times: user 2.62 ms, sys: 14.3 ms, total: 17 ms
# Wall time: 18.8 ms
# CPU times: user 1.7 ms, sys: 0 ns, total: 1.7 ms
# Wall time: 3.24 ms
# CPU times: user 617 µs, sys: 911 µs, total: 1.53 ms
# Wall time: 1.79 ms
# CPU times: user 57.9 ms, sys: 803 ms, total: 861 ms
# Wall time: 8.28 s
# CPU times: user 106 ms, sys: 1.04 s, total: 1.14 s
# Wall time: 9.5 s
# CPU times: user 41.9 ms, sys: 1.18 s, total: 1.23 s
# Wall time: 9.44 s
# CPU times: user 3.78 ms, sys: 1.63 ms, total: 5.42 ms
# Wall time: 749 ms
# CPU times: user 5.71 ms, sys: 0 ns, total: 5.71 ms
# Wall time: 397 ms
# CPU times: user 3.3 ms, sys: 704 µs, total: 4 ms
# Wall time: 358 ms

# %%
print(X3_valp1.shape)
print(X3_valp2.shape)
print(X3_valp3.shape)
print(X3_testp1.shape)
print(X3_testp2.shape)
print(X3_testp3.shape)

# %%
from tensorflow.keras.utils import to_categorical
y3_valp1 = to_categorical(y3_valp1.cpu(), num_classes=2)
y3_valp2 = to_categorical(y3_valp2.cpu(), num_classes=2)
y3_valp3 = to_categorical(y3_valp3.cpu(), num_classes=2)

y3_testp1 = to_categorical(y3_testp1.cpu(), num_classes=2)
y3_testp2 = to_categorical(y3_testp2.cpu(), num_classes=2)
y3_testp3 = to_categorical(y3_testp3.cpu(), num_classes=2)

# %%
#validacion
modelo3.evaluate(np.asarray(X3_valp1.cpu()), np.asarray(y3_valp1),verbose=2)
modelo3.evaluate(np.asarray(X3_valp2.cpu()), np.asarray(y3_valp2),verbose=2)
modelo3.evaluate(np.asarray(X3_valp3.cpu()), np.asarray(y3_valp3),verbose=2)
# Out:
# 469/469 - 2s - loss: 0.2871 - categorical_accuracy: 0.9367 - 2s/epoch - 4ms/step
# 469/469 - 1s - loss: 0.3269 - categorical_accuracy: 0.9308 - 1s/epoch - 2ms/step
# 471/471 - 1s - loss: 0.3202 - categorical_accuracy: 0.9305 - 1s/epoch - 3ms/step
# [0.3202492296695709, 0.9304613471031189]

# %%
modelo3.save('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo3DenseEvaluate.h5')

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix

with torch.no_grad():
  y3_test = np.concatenate((y3_testp1, y3_testp2,y3_testp3), axis=0)
  X3_test = torch.cat((X3_testp1.cpu(),X3_testp2.cpu(),X3_testp3.cpu()),0)
  y3_predictions = modelo3.predict(np.asarray(X3_test),verbose=2).round()
  print(len(y3_predictions))
  confusion = multilabel_confusion_matrix(y3_test,y3_predictions)
  print(f"acc: {accuracy_score(y3_test,y3_predictions)}")
  print(f"precision: {precision_score(y3_test,y3_predictions,average='macro')}")
  print(f"recall: {recall_score(y3_test,y3_predictions,average='macro')}")
  print(f"f1: {f1_score(y3_test,y3_predictions,average='micro')}")
  confusion_display = ConfusionMatrixDisplay(confusion[0],display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# # Resultados

# %% [markdown]
# Utilizando el conjunto de prueba

# %% [markdown]
# Utilizando el conjunto de validacion

# %% [markdown]
# # Conclusiones
# De un total de 150 observaciones, 4 caracteristicas y 3 etiquetas de clasificacion, se ha demostrado que el modelo presentado logra clasificar con un accuracy de 93% para el conjunto de prueba y un 100% para el conjunto de validación.

# %% [markdown]
# # Nueva sección

# %% [markdown]
# ## Modelo1

# %%
from keras.models import load_model
modelo1 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo1DenseEvaluate.h5')

# %%
# %time X1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp0.pt')
# %time X1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp1.pt')
# %time X1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp2.pt')
# %time y1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp0.pt')
# %time y1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp1.pt')
# %time y1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y1_testp1 = to_categorical(y1_testp1.cpu(), num_classes=2)
y1_testp2 = to_categorical(y1_testp2.cpu(), num_classes=2)
y1_testp3 = to_categorical(y1_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y1_test = np.concatenate((y1_testp1, y1_testp2,y1_testp3), axis=0)
  X1_test = torch.cat((X1_testp1.cpu(),X1_testp2.cpu(),X1_testp3.cpu()),0)
  del X1_testp1
  del X1_testp2
  del X1_testp3
  del y1_testp1
  del y1_testp2
  del y1_testp3
# Out:
# CPU times: user 262 ms, sys: 515 ms, total: 778 ms
# Wall time: 3.31 s
# CPU times: user 237 ms, sys: 432 ms, total: 669 ms
# Wall time: 3.29 s
# CPU times: user 263 ms, sys: 527 ms, total: 789 ms
# Wall time: 3.8 s
# CPU times: user 1.61 ms, sys: 13.5 ms, total: 15.1 ms
# Wall time: 17.4 ms
# CPU times: user 2.1 ms, sys: 0 ns, total: 2.1 ms
# Wall time: 2.27 ms
# CPU times: user 354 µs, sys: 1.58 ms, total: 1.93 ms
# Wall time: 2.33 ms

# %%
# %time X2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp0.pt')
# %time X2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp1.pt')
# %time X2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp2.pt')
# %time y2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp0.pt')
# %time y2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp1.pt')
# %time y2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y2_testp1 = to_categorical(y2_testp1.cpu(), num_classes=2)
y2_testp2 = to_categorical(y2_testp2.cpu(), num_classes=2)
y2_testp3 = to_categorical(y2_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y2_test = np.concatenate((y2_testp1, y2_testp2,y2_testp3), axis=0)
  X2_test = torch.cat((X2_testp1.cpu(),X2_testp2.cpu(),X2_testp3.cpu()),0)
  del X2_testp1
  del X2_testp2
  del X2_testp3
  del y2_testp1
  del y2_testp2
  del y2_testp3
# Out:
# CPU times: user 237 ms, sys: 445 ms, total: 682 ms
# Wall time: 3.3 s
# CPU times: user 238 ms, sys: 435 ms, total: 673 ms
# Wall time: 3.3 s
# CPU times: user 249 ms, sys: 517 ms, total: 766 ms
# Wall time: 2.82 s
# CPU times: user 1.17 ms, sys: 1.14 ms, total: 2.31 ms
# Wall time: 3.13 ms
# CPU times: user 1.33 ms, sys: 661 µs, total: 1.99 ms
# Wall time: 3.21 ms
# CPU times: user 1.32 ms, sys: 889 µs, total: 2.21 ms
# Wall time: 3.6 ms

# %%
# %time X3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp0.pt')
# %time X3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp1.pt')
# %time X3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp2.pt')
# %time y3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp0.pt')
# %time y3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp1.pt')
# %time y3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y3_testp1 = to_categorical(y3_testp1.cpu(), num_classes=2)
y3_testp2 = to_categorical(y3_testp2.cpu(), num_classes=2)
y3_testp3 = to_categorical(y3_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y3_test = np.concatenate((y3_testp1, y3_testp2,y3_testp3), axis=0)
  X3_test = torch.cat((X3_testp1.cpu(),X3_testp2.cpu(),X3_testp3.cpu()),0)
  del X3_testp1
  del X3_testp2
  del X3_testp3
  del y3_testp1
  del y3_testp2
  del y3_testp3
# Out:
# CPU times: user 253 ms, sys: 528 ms, total: 781 ms
# Wall time: 3.32 s
# CPU times: user 223 ms, sys: 449 ms, total: 672 ms
# Wall time: 3.33 s
# CPU times: user 267 ms, sys: 543 ms, total: 809 ms
# Wall time: 3.82 s
# CPU times: user 2.4 ms, sys: 0 ns, total: 2.4 ms
# Wall time: 6.14 ms
# CPU times: user 442 µs, sys: 1.43 ms, total: 1.87 ms
# Wall time: 3.97 ms
# CPU times: user 1.84 ms, sys: 221 µs, total: 2.06 ms
# Wall time: 2.17 ms

# %%
del modelo1
del y1_predictions
del y2_predictions
del y3_predictions

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
y1predict = {}
y2predict = {}
y3predict = {}
with torch.no_grad():
  y1_predictions = modelo1.predict(np.asarray(X1_test.cpu()),verbose=2).round()
  y2_predictions = modelo1.predict(np.asarray(X2_test.cpu()),verbose=2).round()
  y3_predictions = modelo1.predict(np.asarray(X3_test.cpu()),verbose=2).round()
  #print(len(y1_predictions))
  #confusion = multilabel_confusion_matrix(y1_test,y1_predictions)
  print(f"acc: {round(accuracy_score(y1_test,y1_predictions),3)} | {round(accuracy_score(y2_test,y2_predictions),3)} | {round(accuracy_score(y3_test,y3_predictions),3)}   ")
  print(f"precision: {round(precision_score(y1_test,y1_predictions,average='macro'),3)} | {round(precision_score(y2_test,y2_predictions,average='macro'),3)} | {round(precision_score(y3_test,y3_predictions,average='macro'),3)} ")
  print(f"recall: {round(recall_score(y1_test,y1_predictions,average='macro'),3)} | {round(recall_score(y2_test,y2_predictions,average='macro'),3)} | {round(recall_score(y3_test,y3_predictions,average='macro'),3)}  ")
  print(f"f1: {round(f1_score(y1_test,y1_predictions,average='micro'),3)} | {round(f1_score(y2_test,y2_predictions,average='micro'),3)} | {round(f1_score(y3_test,y3_predictions,average='micro'),3)}  ")
# Out:
# 986/986 - 5s - 5s/epoch - 5ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# acc: 0.945 | 0.955 | 0.956
# precision: 0.946 | 0.956 | 0.956
# recall: 0.941 | 0.952 | 0.952
# f1: 0.945 | 0.955 | 0.956

# %% [markdown]
# ## Modelo2

# %%
from keras.models import load_model
modelo2 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo2DenseEvaluate.h5')

# %%
# %time X1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp0.pt')
# %time X1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp1.pt')
# %time X1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp2.pt')
# %time y1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp0.pt')
# %time y1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp1.pt')
# %time y1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y1_testp1 = to_categorical(y1_testp1.cpu(), num_classes=2)
y1_testp2 = to_categorical(y1_testp2.cpu(), num_classes=2)
y1_testp3 = to_categorical(y1_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y1_test = np.concatenate((y1_testp1, y1_testp2,y1_testp3), axis=0)
  X1_test = torch.cat((X1_testp1.cpu(),X1_testp2.cpu(),X1_testp3.cpu()),0)
  del X1_testp1
  del X1_testp2
  del X1_testp3
  del y1_testp1
  del y1_testp2
  del y1_testp3
# Out:
# CPU times: user 448 ms, sys: 710 ms, total: 1.16 s
# Wall time: 3.32 s
# CPU times: user 260 ms, sys: 433 ms, total: 692 ms
# Wall time: 3.3 s
# CPU times: user 265 ms, sys: 558 ms, total: 823 ms
# Wall time: 3.81 s
# CPU times: user 2.38 ms, sys: 13.6 ms, total: 15.9 ms
# Wall time: 18.5 ms
# CPU times: user 1.09 ms, sys: 421 µs, total: 1.51 ms
# Wall time: 2.39 ms
# CPU times: user 1.89 ms, sys: 0 ns, total: 1.89 ms
# Wall time: 2.02 ms

# %%
# %time X2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp0.pt')
# %time X2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp1.pt')
# %time X2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp2.pt')
# %time y2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp0.pt')
# %time y2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp1.pt')
# %time y2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y2_testp1 = to_categorical(y2_testp1.cpu(), num_classes=2)
y2_testp2 = to_categorical(y2_testp2.cpu(), num_classes=2)
y2_testp3 = to_categorical(y2_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y2_test = np.concatenate((y2_testp1, y2_testp2,y2_testp3), axis=0)
  X2_test = torch.cat((X2_testp1.cpu(),X2_testp2.cpu(),X2_testp3.cpu()),0)
  del X2_testp1
  del X2_testp2
  del X2_testp3
  del y2_testp1
  del y2_testp2
  del y2_testp3
# Out:
# CPU times: user 239 ms, sys: 473 ms, total: 713 ms
# Wall time: 3.3 s
# CPU times: user 232 ms, sys: 474 ms, total: 706 ms
# Wall time: 3.3 s
# CPU times: user 234 ms, sys: 572 ms, total: 805 ms
# Wall time: 2.18 s
# CPU times: user 2.47 ms, sys: 335 µs, total: 2.81 ms
# Wall time: 2.86 ms
# CPU times: user 1.92 ms, sys: 0 ns, total: 1.92 ms
# Wall time: 1.94 ms
# CPU times: user 1.43 ms, sys: 294 µs, total: 1.72 ms
# Wall time: 1.77 ms

# %%
# %time X3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp0.pt')
# %time X3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp1.pt')
# %time X3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp2.pt')
# %time y3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp0.pt')
# %time y3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp1.pt')
# %time y3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y3_testp1 = to_categorical(y3_testp1.cpu(), num_classes=2)
y3_testp2 = to_categorical(y3_testp2.cpu(), num_classes=2)
y3_testp3 = to_categorical(y3_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y3_test = np.concatenate((y3_testp1, y3_testp2,y3_testp3), axis=0)
  X3_test = torch.cat((X3_testp1.cpu(),X3_testp2.cpu(),X3_testp3.cpu()),0)
  del X3_testp1
  del X3_testp2
  del X3_testp3
  del y3_testp1
  del y3_testp2
  del y3_testp3
# Out:
# CPU times: user 253 ms, sys: 590 ms, total: 844 ms
# Wall time: 3.33 s
# CPU times: user 227 ms, sys: 505 ms, total: 732 ms
# Wall time: 3.33 s
# CPU times: user 239 ms, sys: 593 ms, total: 831 ms
# Wall time: 3.82 s
# CPU times: user 693 µs, sys: 1.66 ms, total: 2.35 ms
# Wall time: 8.91 ms
# CPU times: user 869 µs, sys: 886 µs, total: 1.75 ms
# Wall time: 3.08 ms
# CPU times: user 1.17 ms, sys: 718 µs, total: 1.89 ms
# Wall time: 1.92 ms

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
y1predict = {}
y2predict = {}
y3predict = {}
with torch.no_grad():
  y1_predictions = modelo2.predict(np.asarray(X1_test.cpu()),verbose=2).round()
  y2_predictions = modelo2.predict(np.asarray(X2_test.cpu()),verbose=2).round()
  y3_predictions = modelo2.predict(np.asarray(X3_test.cpu()),verbose=2).round()
  #print(len(y1_predictions))
  #confusion = multilabel_confusion_matrix(y1_test,y1_predictions)
  print(f"acc: {round(accuracy_score(y1_test,y1_predictions),3)} | {round(accuracy_score(y2_test,y2_predictions),3)} | {round(accuracy_score(y3_test,y3_predictions),3)}   ")
  print(f"precision: {round(precision_score(y1_test,y1_predictions,average='macro'),3)} | {round(precision_score(y2_test,y2_predictions,average='macro'),3)} | {round(precision_score(y3_test,y3_predictions,average='macro'),3)} ")
  print(f"recall: {round(recall_score(y1_test,y1_predictions,average='macro'),3)} | {round(recall_score(y2_test,y2_predictions,average='macro'),3)} | {round(recall_score(y3_test,y3_predictions,average='macro'),3)}  ")
  print(f"f1: {round(f1_score(y1_test,y1_predictions,average='micro'),3)} | {round(f1_score(y2_test,y2_predictions,average='micro'),3)} | {round(f1_score(y3_test,y3_predictions,average='micro'),3)}  ")
# Out:
# 986/986 - 2s - 2s/epoch - 2ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# acc: 0.943 | 0.931 | 0.945
# precision: 0.943 | 0.929 | 0.944
# recall: 0.94 | 0.927 | 0.942
# f1: 0.943 | 0.931 | 0.945

# %% [markdown]
# ## Modelo3

# %%
from keras.models import load_model
modelo3 = load_model('/content/drive/MyDrive/Colab Notebooks/dataset/tesis/fakeNewsNet/muestras/modelos/modelo3DenseEvaluate.h5')

# %%
# %time X1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp0.pt')
# %time X1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp1.pt')
# %time X1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X1_test/X1_test_tensorp2.pt')
# %time y1_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp0.pt')
# %time y1_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp1.pt')
# %time y1_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y1_test/y1_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y1_testp1 = to_categorical(y1_testp1.cpu(), num_classes=2)
y1_testp2 = to_categorical(y1_testp2.cpu(), num_classes=2)
y1_testp3 = to_categorical(y1_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y1_test = np.concatenate((y1_testp1, y1_testp2,y1_testp3), axis=0)
  X1_test = torch.cat((X1_testp1.cpu(),X1_testp2.cpu(),X1_testp3.cpu()),0)
  del X1_testp1
  del X1_testp2
  del X1_testp3
  del y1_testp1
  del y1_testp2
  del y1_testp3
# Out:
# CPU times: user 239 ms, sys: 712 ms, total: 951 ms
# Wall time: 3.32 s
# CPU times: user 203 ms, sys: 473 ms, total: 677 ms
# Wall time: 3.3 s
# CPU times: user 256 ms, sys: 579 ms, total: 835 ms
# Wall time: 3.82 s
# CPU times: user 678 µs, sys: 1.33 ms, total: 2 ms
# Wall time: 6.27 ms
# CPU times: user 2.11 ms, sys: 0 ns, total: 2.11 ms
# Wall time: 2.38 ms
# CPU times: user 1.69 ms, sys: 0 ns, total: 1.69 ms
# Wall time: 1.76 ms

# %%
# %time X2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp0.pt')
# %time X2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp1.pt')
# %time X2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X2_test/X2_test_tensorp2.pt')
# %time y2_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp0.pt')
# %time y2_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp1.pt')
# %time y2_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y2_test/y2_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y2_testp1 = to_categorical(y2_testp1.cpu(), num_classes=2)
y2_testp2 = to_categorical(y2_testp2.cpu(), num_classes=2)
y2_testp3 = to_categorical(y2_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y2_test = np.concatenate((y2_testp1, y2_testp2,y2_testp3), axis=0)
  X2_test = torch.cat((X2_testp1.cpu(),X2_testp2.cpu(),X2_testp3.cpu()),0)
  del X2_testp1
  del X2_testp2
  del X2_testp3
  del y2_testp1
  del y2_testp2
  del y2_testp3
# Out:
# CPU times: user 216 ms, sys: 478 ms, total: 694 ms
# Wall time: 3.29 s
# CPU times: user 212 ms, sys: 479 ms, total: 691 ms
# Wall time: 3.28 s
# CPU times: user 244 ms, sys: 519 ms, total: 763 ms
# Wall time: 2.16 s
# CPU times: user 3.8 ms, sys: 16.3 ms, total: 20.1 ms
# Wall time: 18.9 ms
# CPU times: user 1.07 ms, sys: 1.07 ms, total: 2.14 ms
# Wall time: 2.64 ms
# CPU times: user 1.67 ms, sys: 274 µs, total: 1.95 ms
# Wall time: 1.96 ms

# %%
# %time X3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp0.pt')
# %time X3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp1.pt')
# %time X3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/X3_test/X3_test_tensorp2.pt')
# %time y3_testp1 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp0.pt')
# %time y3_testp2 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp1.pt')
# %time y3_testp3 = torch.load('/content/drive/MyDrive/fakeNewsNet/muestras/tensores/y3_test/y3_test_tensorp2.pt')
from tensorflow.keras.utils import to_categorical

y3_testp1 = to_categorical(y3_testp1.cpu(), num_classes=2)
y3_testp2 = to_categorical(y3_testp2.cpu(), num_classes=2)
y3_testp3 = to_categorical(y3_testp3.cpu(), num_classes=2)
with torch.no_grad():
  y3_test = np.concatenate((y3_testp1, y3_testp2,y3_testp3), axis=0)
  X3_test = torch.cat((X3_testp1.cpu(),X3_testp2.cpu(),X3_testp3.cpu()),0)
  del X3_testp1
  del X3_testp2
  del X3_testp3
  del y3_testp1
  del y3_testp2
  del y3_testp3
# Out:
# CPU times: user 278 ms, sys: 539 ms, total: 818 ms
# Wall time: 3.36 s
# CPU times: user 208 ms, sys: 480 ms, total: 687 ms
# Wall time: 3.3 s
# CPU times: user 254 ms, sys: 556 ms, total: 810 ms
# Wall time: 3.8 s
# CPU times: user 3.29 ms, sys: 17.6 ms, total: 20.9 ms
# Wall time: 22.6 ms
# CPU times: user 1.37 ms, sys: 329 µs, total: 1.7 ms
# Wall time: 3.12 ms
# CPU times: user 1.8 ms, sys: 0 ns, total: 1.8 ms
# Wall time: 1.91 ms

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
y1predict = {}
y2predict = {}
y3predict = {}
with torch.no_grad():
  y1_predictions = modelo3.predict(np.asarray(X1_test.cpu()),verbose=2).round()
  y2_predictions = modelo3.predict(np.asarray(X2_test.cpu()),verbose=2).round()
  y3_predictions = modelo3.predict(np.asarray(X3_test.cpu()),verbose=2).round()
  #print(len(y1_predictions))
  #confusion = multilabel_confusion_matrix(y1_test,y1_predictions)
  print(f"acc: {round(accuracy_score(y1_test,y1_predictions),3)} | {round(accuracy_score(y2_test,y2_predictions),3)} | {round(accuracy_score(y3_test,y3_predictions),3)}   ")
  print(f"precision: {round(precision_score(y1_test,y1_predictions,average='macro'),3)} | {round(precision_score(y2_test,y2_predictions,average='macro'),3)} | {round(precision_score(y3_test,y3_predictions,average='macro'),3)} ")
  print(f"recall: {round(recall_score(y1_test,y1_predictions,average='macro'),3)} | {round(recall_score(y2_test,y2_predictions,average='macro'),3)} | {round(recall_score(y3_test,y3_predictions,average='macro'),3)}  ")
  print(f"f1: {round(f1_score(y1_test,y1_predictions,average='micro'),3)} | {round(f1_score(y2_test,y2_predictions,average='micro'),3)} | {round(f1_score(y3_test,y3_predictions,average='micro'),3)}  ")
# Out:
# 986/986 - 2s - 2s/epoch - 2ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# 986/986 - 2s - 2s/epoch - 2ms/step
# acc: 0.946 | 0.947 | 0.934
# precision: 0.945 | 0.945 | 0.932
# recall: 0.944 | 0.945 | 0.931
# f1: 0.946 | 0.947 | 0.934
