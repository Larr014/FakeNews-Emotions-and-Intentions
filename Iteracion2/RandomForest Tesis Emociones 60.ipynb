# %%
from google.colab import drive  # to mount Drive to Colab notebook
import csv
import time
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Connect Google Drive to Colab
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import joblib
# %time X1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_train60.joblib')
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test60.joblib')
# %time y1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_train60.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test60.joblib')
# Out:
# CPU times: user 6.44 s, sys: 225 ms, total: 6.67 s
# Wall time: 12.2 s
# CPU times: user 6.49 s, sys: 224 ms, total: 6.71 s
# Wall time: 6.91 s
# CPU times: user 8.36 ms, sys: 894 µs, total: 9.26 ms
# Wall time: 340 ms
# CPU times: user 5.66 ms, sys: 1.95 ms, total: 7.61 ms
# Wall time: 220 ms

# %%
def train(X,y):
  modelo = RandomForestClassifier(random_state=0, verbose=2, n_estimators=100 , n_jobs=8)
  modelo.fit(X,y)
  return modelo

# %%
# %time modelo1 = train(X1_train,y1_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   40.3s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100building tree 91 of 100
#
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 3min 56s, sys: 850 ms, total: 3min 57s
# Wall time: 2min 10s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.1min finished

# %%
# %time predictions = modelo1.predict(X1_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.54 s, sys: 48 ms, total: 5.59 s
# Wall time: 3.6 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions)
print(f"acc: {accuracy_score(y1_test,predictions)}")
print(f"precision: {precision_score(y1_test,predictions,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions,average='micro')}")
# Out:
# acc: 0.9311871481879704
# precision: 0.9323215942780495
# recall: 0.9252291841888801
# f1: 0.9311871481879704

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# Probando modelo con muestra 2 y 3

# %%
import joblib
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test60.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test60.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test60.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test60.joblib')
# Out:
# CPU times: user 6.54 s, sys: 290 ms, total: 6.83 s
# Wall time: 6.82 s
# CPU times: user 8.39 ms, sys: 1.01 ms, total: 9.4 ms
# Wall time: 324 ms
# CPU times: user 6.3 s, sys: 192 ms, total: 6.49 s
# Wall time: 7.23 s
# CPU times: user 6.09 ms, sys: 995 µs, total: 7.08 ms
# Wall time: 339 ms

# %%
# %time predictions2 = modelo1.predict(X2_test)
# %time predictions3 = modelo1.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished
# CPU times: user 5.72 s, sys: 39.9 ms, total: 5.76 s
# Wall time: 3.78 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.76 s, sys: 52 ms, total: 5.81 s
# Wall time: 3.86 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9454809942445133
# precision: 0.946167406001444
# recall: 0.9410099652615145
# f1: 0.9454809942445133

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9469356776927456
# precision: 0.9476240019065578
# recall: 0.9425709856044882
# f1: 0.9469356776927456

# %% [markdown]
# ## Muestra 2

# %%
import joblib
# %time X2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_train60.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test60.joblib')
# %time y2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_train60.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test60.joblib')
# Out:
# CPU times: user 6.21 s, sys: 243 ms, total: 6.45 s
# Wall time: 6.61 s
# CPU times: user 5.85 s, sys: 210 ms, total: 6.06 s
# Wall time: 5.88 s
# CPU times: user 6.34 ms, sys: 3.01 ms, total: 9.36 ms
# Wall time: 329 ms
# CPU times: user 4.82 ms, sys: 5 µs, total: 4.82 ms
# Wall time: 6.18 ms

# %%
# %time modelo2 = train(X2_train,y2_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   41.0s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 3min 56s, sys: 737 ms, total: 3min 57s
# Wall time: 2min 8s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.1min finished

# %%
# %time predictions2 = modelo2.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.01 s, sys: 22.1 ms, total: 6.04 s
# Wall time: 4.2 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9265068623110493
# precision: 0.9276687282861795
# recall: 0.9201610931276164
# f1: 0.9265068623110493

# %% [markdown]
# Probando modelo con muestra 1 y 3

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test60.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test60.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test60.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test60.joblib')
# Out:
# CPU times: user 5.6 s, sys: 267 ms, total: 5.87 s
# Wall time: 5.59 s
# CPU times: user 5.55 ms, sys: 2 µs, total: 5.56 ms
# Wall time: 6.1 ms
# CPU times: user 6.26 s, sys: 186 ms, total: 6.44 s
# Wall time: 6.33 s
# CPU times: user 4.05 ms, sys: 995 µs, total: 5.04 ms
# Wall time: 7.58 ms

# %%
# %time predictions1 = modelo2.predict(X1_test)
# %time predictions3 = modelo2.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished
# CPU times: user 6.2 s, sys: 28.9 ms, total: 6.23 s
# Wall time: 4.26 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.22 s, sys: 25.9 ms, total: 5.25 s
# Wall time: 3.66 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.9466194421605212
# precision: 0.9478267477310596
# recall: 0.941765719960542
# f1: 0.9466194421605212

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9461450888621845
# precision: 0.9470865606429182
# recall: 0.9414916784092975
# f1: 0.9461450888621845

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# ## Muestra 3

# %%
import joblib
# %time X3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_train60.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test60.joblib')
# %time y3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_train60.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test60.joblib')
# Out:
# CPU times: user 6.19 s, sys: 148 ms, total: 6.34 s
# Wall time: 6.53 s
# CPU times: user 8.06 s, sys: 158 ms, total: 8.21 s
# Wall time: 9.24 s
# CPU times: user 8.84 ms, sys: 2.01 ms, total: 10.9 ms
# Wall time: 814 ms
# CPU times: user 2.81 ms, sys: 1 ms, total: 3.81 ms
# Wall time: 5 ms

# %%
# %time modelo3 = train(X3_train,y3_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
#
# building tree 5 of 100
# building tree 6 of 100building tree 7 of 100
# building tree 8 of 100
#
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100building tree 20 of 100
#
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   39.9s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 3min 56s, sys: 796 ms, total: 3min 57s
# Wall time: 2min 7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.1min finished

# %%
# %time predictions3 = modelo3.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.25 s, sys: 45.9 ms, total: 6.29 s
# Wall time: 4.36 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res3 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9286572639301752
# precision: 0.9300240132356814
# recall: 0.9223006956787747
# f1: 0.9286572639301752

# %% [markdown]
# Probando modelo con muestra 1 y 2

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test60.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test60.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test60.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test60.joblib')
# Out:
# CPU times: user 6.41 s, sys: 218 ms, total: 6.63 s
# Wall time: 6.5 s
# CPU times: user 4.39 ms, sys: 1.14 ms, total: 5.53 ms
# Wall time: 6.66 ms
# CPU times: user 7.29 s, sys: 123 ms, total: 7.41 s
# Wall time: 7.28 s
# CPU times: user 6.14 ms, sys: 1 ms, total: 7.15 ms
# Wall time: 7.49 ms

# %%
# %time predictions1 = modelo3.predict(X1_test)
# %time predictions2 = modelo3.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.2s finished
# CPU times: user 5.58 s, sys: 25.2 ms, total: 5.6 s
# Wall time: 3.65 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 6.31 s, sys: 28.3 ms, total: 6.34 s
# Wall time: 4.32 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.1s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.9465878186072987
# precision: 0.9477470484721
# recall: 0.9417739098030415
# f1: 0.9465878186072987

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9451647587122889
# precision: 0.9461195166263857
# recall: 0.9404264906348035
# f1: 0.9451647587122889

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res3,display_labels=['fake','noFake']).plot(values_format='d')
