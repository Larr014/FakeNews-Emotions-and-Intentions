# %%
from google.colab import drive  # to mount Drive to Colab notebook
import csv
import time
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Connect Google Drive to Colab
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import joblib
# %time X1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_train80.joblib')
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test80.joblib')
# %time y1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_train80.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test80.joblib')
# Out:
# CPU times: user 6.3 s, sys: 266 ms, total: 6.57 s
# Wall time: 10.7 s
# CPU times: user 6.44 s, sys: 248 ms, total: 6.69 s
# Wall time: 7.09 s
# CPU times: user 8.51 ms, sys: 3.18 ms, total: 11.7 ms
# Wall time: 418 ms
# CPU times: user 4.83 ms, sys: 1.11 ms, total: 5.95 ms
# Wall time: 397 ms

# %%
def train(X,y):
  modelo = RandomForestClassifier(random_state=0, verbose=2, n_estimators=100 , n_jobs=8)
  modelo.fit(X,y)
  return modelo

# %%
# %time modelo1 = train(X1_train,y1_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   43.7s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 4min 11s, sys: 853 ms, total: 4min 12s
# Wall time: 2min 17s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.3min finished

# %%
# %time predictions = modelo1.predict(X1_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.43 s, sys: 58.1 ms, total: 6.48 s
# Wall time: 4.3 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions)
print(f"acc: {accuracy_score(y1_test,predictions)}")
print(f"precision: {precision_score(y1_test,predictions,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions,average='micro')}")
# Out:
# acc: 0.9309974068686357
# precision: 0.9311385424937573
# recall: 0.9259436962955829
# f1: 0.9309974068686357

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# Probando modelo con muestra 2 y 3

# %%
import joblib
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test80.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test80.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test80.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test80.joblib')
# Out:
# CPU times: user 6.36 s, sys: 276 ms, total: 6.63 s
# Wall time: 6.96 s
# CPU times: user 4.34 ms, sys: 4 ms, total: 8.35 ms
# Wall time: 370 ms
# CPU times: user 5.69 s, sys: 179 ms, total: 5.86 s
# Wall time: 6.23 s
# CPU times: user 8.26 ms, sys: 29 µs, total: 8.29 ms
# Wall time: 356 ms

# %%
# %time predictions2 = modelo1.predict(X2_test)
# %time predictions3 = modelo1.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.9s finished
# CPU times: user 6.24 s, sys: 34.9 ms, total: 6.27 s
# Wall time: 4.4 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.28 s, sys: 49.9 ms, total: 6.33 s
# Wall time: 4.06 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.4s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9457023591170703
# precision: 0.9458140091405304
# recall: 0.9417931075872255
# f1: 0.9457023591170703

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9478843842894188
# precision: 0.9482403540765212
# recall: 0.9439011738730173
# f1: 0.9478843842894188

# %% [markdown]
# ## Muestra 2

# %%
import joblib
# %time X2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_train80.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test80.joblib')
# %time y2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_train80.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test80.joblib')
# Out:
# CPU times: user 6.16 s, sys: 217 ms, total: 6.37 s
# Wall time: 6.82 s
# CPU times: user 5.6 s, sys: 241 ms, total: 5.84 s
# Wall time: 5.51 s
# CPU times: user 7.4 ms, sys: 4.01 ms, total: 11.4 ms
# Wall time: 506 ms
# CPU times: user 4.39 ms, sys: 4 µs, total: 4.4 ms
# Wall time: 5.77 ms

# %%
# %time modelo2 = train(X2_train,y2_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100building tree 5 of 100
#
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100building tree 31 of 100
#
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   41.9s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100building tree 62 of 100
#
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100building tree 67 of 100
#
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 4min 13s, sys: 813 ms, total: 4min 13s
# Wall time: 2min 18s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.3min finished

# %%
# %time predictions2 = modelo2.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    1.3s
# CPU times: user 7.1 s, sys: 40.5 ms, total: 7.14 s
# Wall time: 7.34 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    4.3s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9267598507368288
# precision: 0.9267668026357075
# recall: 0.9215080329710663
# f1: 0.9267598507368289

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# Probando modelo con muestra 1 y 3

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test80.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test80.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test80.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test80.joblib')
# Out:
# CPU times: user 5.52 s, sys: 209 ms, total: 5.73 s
# Wall time: 5.6 s
# CPU times: user 4.63 ms, sys: 10 µs, total: 4.64 ms
# Wall time: 4.99 ms
# CPU times: user 6.03 s, sys: 162 ms, total: 6.19 s
# Wall time: 5.95 s
# CPU times: user 4.34 ms, sys: 2 µs, total: 4.34 ms
# Wall time: 4.73 ms

# %%
# %time predictions1 = modelo2.predict(X1_test)
# %time predictions3 = modelo2.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.6s finished
# CPU times: user 6.89 s, sys: 43.1 ms, total: 6.93 s
# Wall time: 4.81 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.59 s, sys: 32.6 ms, total: 6.62 s
# Wall time: 4.65 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.8s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.9453228764784011
# precision: 0.9454661914928353
# recall: 0.9413544179712813
# f1: 0.9453228764784011

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9466194421605212
# precision: 0.9468602341301814
# recall: 0.9426528840294832
# f1: 0.9466194421605212

# %% [markdown]
# ## Muestra 3

# %%
import joblib
# %time X3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_train80.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test80.joblib')
# %time y3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_train80.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test80.joblib')
# Out:
# CPU times: user 5.71 s, sys: 189 ms, total: 5.9 s
# Wall time: 6.26 s
# CPU times: user 6.6 s, sys: 239 ms, total: 6.84 s
# Wall time: 6.53 s
# CPU times: user 10.5 ms, sys: 4.01 ms, total: 14.5 ms
# Wall time: 431 ms
# CPU times: user 4.67 ms, sys: 11 µs, total: 4.68 ms
# Wall time: 6.43 ms

# %%
# %time modelo3 = train(X3_train,y3_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
#
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   41.5s
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# CPU times: user 4min 13s, sys: 790 ms, total: 4min 14s
# Wall time: 2min 15s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:  2.2min finished

# %%
# %time predictions3 = modelo3.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 6.96 s, sys: 51.9 ms, total: 7.02 s
# Wall time: 4.73 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res3 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9295427234204036
# precision: 0.9296893066580258
# recall: 0.9243710027411758
# f1: 0.9295427234204036

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res3,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# Probando modelo con muestra 1 y 2

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test80.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test80.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test80.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test80.joblib')
# Out:
# CPU times: user 5.64 s, sys: 231 ms, total: 5.87 s
# Wall time: 5.66 s
# CPU times: user 4.11 ms, sys: 1 ms, total: 5.11 ms
# Wall time: 5.73 ms
# CPU times: user 6.46 s, sys: 155 ms, total: 6.62 s
# Wall time: 6.38 s
# CPU times: user 4.17 ms, sys: 1 ms, total: 5.17 ms
# Wall time: 6.53 ms

# %%
# %time predictions1 = modelo3.predict(X1_test)
# %time predictions2 = modelo3.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.9s finished
# CPU times: user 6.96 s, sys: 29.1 ms, total: 6.99 s
# Wall time: 5.08 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# CPU times: user 5.87 s, sys: 22.9 ms, total: 5.89 s
# Wall time: 3.61 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.9469356776927456
# precision: 0.9472507826278644
# recall: 0.9429211819474913
# f1: 0.9469356776927456

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9443109227752831
# precision: 0.9445310609671849
# recall: 0.9401923611363858
# f1: 0.9443109227752831
