# %%
from google.colab import drive  # to mount Drive to Colab notebook
import csv
import time
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Connect Google Drive to Colab
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import joblib
# %time X1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_train40.joblib')
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test40.joblib')
# %time y1_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_train40.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test40.joblib')
# Out:
# CPU times: user 6.45 s, sys: 313 ms, total: 6.76 s
# Wall time: 6.47 s
# CPU times: user 6.74 s, sys: 200 ms, total: 6.94 s
# Wall time: 6.72 s
# CPU times: user 5.79 ms, sys: 2.11 ms, total: 7.9 ms
# Wall time: 8.91 ms
# CPU times: user 2.9 ms, sys: 1.09 ms, total: 3.99 ms
# Wall time: 5.49 ms

# %%
def train(X,y):
  modelo = RandomForestClassifier(random_state=0, verbose=2, n_estimators=100 , n_jobs=8)
  modelo.fit(X,y)
  return modelo

# %%
# %time modelo1 = train(X1_train,y1_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100building tree 5 of 100
#
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   40.3s
# building tree 33 of 100
# ...

# %%
# %time predictions = modelo1.predict(X1_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.26 s, sys: 71 ms, total: 5.33 s
# Wall time: 3.51 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions)
print(f"acc: {accuracy_score(y1_test,predictions)}")
print(f"precision: {precision_score(y1_test,predictions,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions,average='micro')}")
# Out:
# acc: 0.9263171209917146
# precision: 0.9286111491524391
# recall: 0.9190078914049693
# f1: 0.9263171209917146

# %% [markdown]
# Probando modelo con muestra 2 y 3

# %%
import joblib
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test40.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test40.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test40.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test40.joblib')
# Out:
# CPU times: user 6.39 s, sys: 234 ms, total: 6.62 s
# Wall time: 6.47 s
# CPU times: user 4.62 ms, sys: 998 µs, total: 5.62 ms
# Wall time: 6.78 ms
# CPU times: user 5.94 s, sys: 238 ms, total: 6.18 s
# Wall time: 5.94 s
# CPU times: user 5.15 ms, sys: 8 µs, total: 5.16 ms
# Wall time: 5.74 ms

# %%
# %time predictions2 = modelo1.predict(X2_test)
# %time predictions3 = modelo1.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished
# CPU times: user 5.45 s, sys: 30.9 ms, total: 5.48 s
# Wall time: 3.66 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.9 s, sys: 64.2 ms, total: 5.97 s
# Wall time: 4.11 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.1s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9428246157738284
# precision: 0.944240289988109
# recall: 0.9375072291268682
# f1: 0.9428246157738284

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9428246157738284
# precision: 0.9445852749258733
# recall: 0.9372153988410323
# f1: 0.9428246157738284

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# ## Muestra 2

# %%
import joblib
# %time X2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_train40.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test40.joblib')
# %time y2_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_train40.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test40.joblib')
# Out:
# CPU times: user 6.55 s, sys: 241 ms, total: 6.79 s
# Wall time: 6.6 s
# CPU times: user 5.65 s, sys: 247 ms, total: 5.89 s
# Wall time: 5.64 s
# CPU times: user 6.68 ms, sys: 1 ms, total: 7.68 ms
# Wall time: 8.53 ms
# CPU times: user 3.98 ms, sys: 0 ns, total: 3.98 ms
# Wall time: 5.17 ms

# %%
# %time modelo2 = train(X2_train,y2_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
#
# building tree 7 of 100building tree 8 of 100
#
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   40.1s
# ...

# %%
# %time predictions2 = modelo2.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.73 s, sys: 40.9 ms, total: 5.77 s
# Wall time: 3.94 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.1s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9233128834355828
# precision: 0.9249497597398053
# recall: 0.9163073094352572
# f1: 0.9233128834355828

# %% [markdown]
# Probando modelo con muestra 1 y 3

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test40.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test40.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test40.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test40.joblib')
# Out:
# CPU times: user 6.15 s, sys: 259 ms, total: 6.4 s
# Wall time: 6.17 s
# CPU times: user 5.22 ms, sys: 1 µs, total: 5.22 ms
# Wall time: 5.82 ms
# CPU times: user 6.48 s, sys: 157 ms, total: 6.64 s
# Wall time: 6.37 s
# CPU times: user 4.62 ms, sys: 5 µs, total: 4.62 ms
# Wall time: 5.23 ms

# %%
# %time predictions1 = modelo2.predict(X1_test)
# %time predictions3 = modelo2.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished
# CPU times: user 6.24 s, sys: 30.1 ms, total: 6.27 s
# Wall time: 4.48 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# CPU times: user 5.07 s, sys: 27 ms, total: 5.09 s
# Wall time: 3.23 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.9424767566883815
# precision: 0.9441154664657856
# recall: 0.9369436175540902
# f1: 0.9424767566883815

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9445006640946176
# precision: 0.9462964996124557
# recall: 0.9389875741494786
# f1: 0.9445006640946176

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res2,display_labels=['fake','noFake']).plot(values_format='d')

# %% [markdown]
# ## Muestra 3

# %%
import joblib
# %time X3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_train40.joblib')
# %time X3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X3_test40.joblib')
# %time y3_train = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_train40.joblib')
# %time y3_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y3_test40.joblib')
# Out:
# CPU times: user 5.67 s, sys: 180 ms, total: 5.85 s
# Wall time: 5.73 s
# CPU times: user 6.73 s, sys: 225 ms, total: 6.95 s
# Wall time: 6.63 s
# CPU times: user 6.22 ms, sys: 2 ms, total: 8.22 ms
# Wall time: 9.72 ms
# CPU times: user 3.31 ms, sys: 0 ns, total: 3.31 ms
# Wall time: 4.68 ms

# %%
# %time modelo3 = train(X3_train,y3_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   39.9s
# building tree 33 of 100
# ...

# %%
# %time predictions3 = modelo3.predict(X3_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.5s
# CPU times: user 6.15 s, sys: 38.1 ms, total: 6.19 s
# Wall time: 4.75 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.4s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res3 = confusion_matrix(y3_test, predictions3)
print(f"acc: {accuracy_score(y3_test,predictions3)}")
print(f"precision: {precision_score(y3_test,predictions3,average='macro')}")
print(f"recall: {recall_score(y3_test,predictions3,average='macro')}")
print(f"f1: {f1_score(y3_test,predictions3,average='micro')}")
# Out:
# acc: 0.9242299664790335
# precision: 0.9263768809151807
# recall: 0.916875255591679
# f1: 0.9242299664790335

# %% [markdown]
# Probando modelo con muestra 1 y 2

# %%
import joblib
# %time X1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X1_test40.joblib')
# %time y1_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y1_test40.joblib')
# %time X2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_X2_test40.joblib')
# %time y2_test = joblib.load('/gdrive/My Drive/Colab Notebooks/dataset/tesis/fakeNewsNet/Emociones/Muestras/gossipcop_y2_test40.joblib')
# Out:
# CPU times: user 5.5 s, sys: 214 ms, total: 5.71 s
# Wall time: 5.52 s
# CPU times: user 4.98 ms, sys: 0 ns, total: 4.98 ms
# Wall time: 5.33 ms
# CPU times: user 6.93 s, sys: 128 ms, total: 7.06 s
# Wall time: 6.94 s
# CPU times: user 4.06 ms, sys: 0 ns, total: 4.06 ms
# Wall time: 5.55 ms

# %%
# %time predictions1 = modelo3.predict(X1_test)
# %time predictions2 = modelo3.predict(X2_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished
# CPU times: user 6.13 s, sys: 38.9 ms, total: 6.16 s
# Wall time: 4.32 s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.5s
# CPU times: user 4.95 s, sys: 31.9 ms, total: 4.98 s
# Wall time: 3.17 s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.0s finished

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y1_test, predictions1)
print(f"acc: {accuracy_score(y1_test,predictions1)}")
print(f"precision: {precision_score(y1_test,predictions1,average='macro')}")
print(f"recall: {recall_score(y1_test,predictions1,average='macro')}")
print(f"f1: {f1_score(y1_test,predictions1,average='micro')}")
# Out:
# acc: 0.943014357093163
# precision: 0.9450252784007342
# recall: 0.9372129526317691
# f1: 0.943014357093163

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
res2 = confusion_matrix(y2_test, predictions2)
print(f"acc: {accuracy_score(y2_test,predictions2)}")
print(f"precision: {precision_score(y2_test,predictions2,average='macro')}")
print(f"recall: {recall_score(y2_test,predictions2,average='macro')}")
print(f"f1: {f1_score(y2_test,predictions2,average='micro')}")
# Out:
# acc: 0.9430776041996078
# precision: 0.9449920572255115
# recall: 0.9373599979068382
# f1: 0.9430776041996078

# %%
from sklearn.metrics import accuracy_score, precision_score, multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix
confusion_display = ConfusionMatrixDisplay(res3,display_labels=['fake','noFake']).plot(values_format='d')
